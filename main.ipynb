# %%
# -*- coding: utf-8 -*-

# 절대 임포트 설정
from __future__ import absolute_import
from __future__ import print_function

# 필요한 라이브러리들을 임포트
import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %%
# Step 1: 필요한 데이터를 다운로드한다.
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """파일이 존재하지 않으면 다운로드하고 사이즈가 적절한지 체크한다."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)

# 문자열로 데이터를 읽는다
def read_data(filename):
  """zip파일 압축을 해제하고 단어들의 리스트를 읽는다."""
  with zipfile.ZipFile(filename) as f:
    data = f.read(f.namelist()[0]).split()
  return data

words = read_data(filename)
print('Data size', len(words))
# Out:
# Found and verified text8.zip
# Data size 17005207

# %%
# Step 2: dictionary를 만들고 UNK 토큰을 이용해서 rare words를 교체(replace)한다.
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], (b'the', 1061396), (b'of', 593677), (b'and', 416629), (b'one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] [b'anarchism', b'originated', b'as', b'a', b'term', b'of', b'abuse', b'first', b'used', b'against']

# %%
# Step 3: skip-gram model을 위한 트레이닝 데이터(batch)를 생성하기 위한 함수.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
      '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 b'originated' -> 5234 b'anarchism'
# 3081 b'originated' -> 12 b'as'
# 12 b'as' -> 6 b'a'
# 12 b'as' -> 3081 b'originated'
# 6 b'a' -> 195 b'term'
# 6 b'a' -> 12 b'as'
# 195 b'term' -> 2 b'of'
# 195 b'term' -> 6 b'a'

# %%
# Step 4: skip-gram model 만들고 학습시킨다.

batch_size = 128
embedding_size = 128  # embedding vector의 크기.
skip_window = 1       # 윈도우 크기 : 왼쪽과 오른쪽으로 얼마나 많은 단어를 고려할지를 결정.
num_skips = 2         # 레이블(label)을 생성하기 위해 인풋을 얼마나 많이 재사용 할 것인지를 결정.

# sample에 대한 validation set은 원래 랜덤하게 선택해야한다. 하지만 여기서는 validation samples을 
# 가장 자주 생성되고 낮은 숫자의 ID를 가진 단어로 제한한다.
valid_size = 16     # validation 사이즈.
valid_window = 100  # 분포의 앞부분(head of the distribution)에서만 validation sample을 선택한다.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # sample에 대한 negative examples의 개수.

graph = tf.Graph()

with graph.as_default():

  # 트레이닝을 위한 인풋 데이터들
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # embedding vectors 행렬을 랜덤값으로 초기화
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    # 행렬에 트레이닝 데이터를 지정
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # NCE loss를 위한 변수들을 선언
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # batch의 average NCE loss를 계산한다.
  # tf.nce_loss 함수는 loss를 평가(evaluate)할 때마다 negative labels을 가진 새로운 샘플을 자동적으로 생성한다.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # SGD optimizer를 생성한다.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # minibatch examples과 모든 embeddings에 대해 cosine similarity를 계산한다.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

# %%
hello_out = sess.run(embeddings)
print_tf(hello_out)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-e93c1e89b5fe> in <module>()
# ----> 1 hello_out = sess.run(embeddings)
#       2 print_tf(hello_out)
#
# NameError: name 'sess' is not defined

# %%
embeddings
# Out:
# <tf.Variable 'Variable:0' shape=(50000, 128) dtype=float32_ref>

# %%
embed
# Out:
# <tf.Tensor 'embedding_lookup:0' shape=(128, 128) dtype=float32>

# %%
nce_weights
# Out:
# <tf.Variable 'Variable_1:0' shape=(50000, 128) dtype=float32_ref>

# %%
print(nce_biases)
# Out:
# <tf.Variable 'Variable_2:0' shape=(50000,) dtype=float32_ref>

# %%
optimizer
# Out:
# <tf.Operation 'GradientDescent' type=NoOp>

# %%
norm
# Out:
# <tf.Tensor 'Sqrt:0' shape=(50000, 1) dtype=float32>

# %%
normalized_embeddings
# Out:
# <tf.Tensor 'truediv:0' shape=(50000, 128) dtype=float32>

# %%
valid_embeddings
# Out:
# <tf.Tensor 'embedding_lookup_1:0' shape=(16, 128) dtype=float32>

# %%
similarity
# Out:
# <tf.Tensor 'MatMul_1:0' shape=(16, 50000) dtype=float32>

# %%
# Step 5: 트레이닝을 시작한다.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # 트레이닝을 시작하기 전에 모든 변수들을 초기화한다.
  tf.initialize_all_variables().run()
  print("Initialized")

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

    # optimizer op을 평가(evaluating)하면서 한 스텝 업데이트를 진행한다.
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # 평균 손실(average loss)은 지난 2000 배치의 손실(loss)로부터 측정된다.
      print("Average loss at step ", step, ": ", average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # nearest neighbors의 개수
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log_str = "Nearest to %s:" % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = "%s %s," % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From C:\Users\Adonishan\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\util\tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step  0 :  264.49017333984375
# Nearest to b'in': b'somers', b'eloquent', b'bacillus', b'university', b'qua', b'arrests', b'blatantly', b'didache',
# Nearest to b'six': b'intersputnik', b'poured', b'godly', b'heritability', b'jehoiachin', b'brahmin', b'bypasses', b'uncountably',
# Nearest to b'to': b'regions', b'vah', b'flugelhorn', b'ncp', b'integrin', b'raeder', b'calculation', b'banishment',
# Nearest to b'on': b'resignations', b'analyzing', b'daiko', b'musculoskeletal', b'robustus', b'assassin', b'mindset', b'rigor',
# Nearest to b'but': b'sighting', b'sloping', b'stabilization', b'magma', b'theoretic', b'godfrey', b'army', b'coulomb',
# Nearest to b'i': b'endowment', b'sported', b'dispersing', b'carloman', b'monosaccharides', b'minix', b'invitation', b'burnside',
# Nearest to b'were': b'boating', b'offical', b'bsi', b'heating', b'ai', b'sacking', b'burgundian', b'framed',
# Nearest to b'such': b'quantifying', b'taiping', b'name', b'magadha', b'lia', b'formulating', b'occupations', b'superboy',
# Nearest to b'there': b'ivens', b'kapoor', b'quetzalcoatl', b'independence', b'constans', b'coagulation', b'decisions', b'demoted',
# Nearest to b'b': b'bluebird', b'domitia', b'jumbled', b'companionship', b'instilled', b'guggenheim', b'universitaire', b'observance',
# Nearest to b'seven': b'producer', b'oneness', b'stages', b'industrial', b'sponsoring', b'afonso', b'ler', b'archeologist',
# Nearest to b'known': b'peabody', b'conducts', b'moivre', b'delinquency', b'firefighters', b'napalm', b'iii', b'cheaper',
# Nearest to b'it': b'witnessing', b'lustrous', b'eclipsing', b'financing', b'americanization', b'scalable', b'escorted', b'safeguards',
# Nearest to b'from': b'lordship', b'majestic', b'merchandising', b'photosynthetic', b'talented', b'flashback', b'ah', b'serpent',
# Nearest to b'nine': b'bacall', b'extended', b'fanaticism', b'icbms', b'hijacker', b'frigates', b'colonna', b'disavowed',
# Nearest to b'more': b'lives', b'exponent', b'bishkek', b'integrable', b'linguist', b'lutherans', b'stanbul', b'braque',
# Average loss at step  2000 :  113.32253475666046
# Average loss at step  4000 :  52.53068793845177
# Average loss at step  6000 :  33.53977004551888
# Average loss at step  8000 :  23.733104781150818
# Average loss at step  10000 :  17.91517973256111
# Nearest to b'in': b'and', b'of', b'with', b'on', b'at', b'by', b'for', b'as',
# Nearest to b'six': b'zero', b'victoriae', b'nine', b'mathbf', b'five', b'reginae', b'altenberg', b'gland',
# Nearest to b'to': b'and', b'of', b'vs', b'victoriae', b'with', b'philosophically', b'in', b'remains',
# Nearest to b'on': b'in', b'and', b'of', b'mathbf', b'msn', b'implicit', b'one', b'jones',
# Nearest to b'but': b'reginae', b'and', b'coulomb', b'which', b'deism', b'yet', b'persons', b'restricted',
# Nearest to b'i': b'sacred', b'endowment', b'depends', b'altenberg', b'burnside', b'draw', b'bed', b'is',
# Nearest to b'were': b'is', b'was', b'and', b'hoare', b'immense', b'forming', b'reich', b'ai',
# Nearest to b'such': b'domicile', b'stayed', b'credits', b'name', b'omotic', b'store', b'servant', b'occupations',
# Nearest to b'there': b'britain', b'independence', b'alice', b'decisions', b'beckwith', b'artist', b'gap', b'class',
# Nearest to b'b': b'companionship', b'mother', b'phi', b'compared', b'familiar', b'brian', b'newer', b'linking',
# Nearest to b'seven': b'nine', b'mathbf', b'victoriae', b'two', b'three', b'six', b'five', b'zero',
# Nearest to b'known': b'iii', b'napalm', b'october', b'rebel', b'cl', b'cheaper', b'arise', b'chains',
# Nearest to b'it': b'altruists', b'cooperation', b'boards', b'extensively', b'amoeboids', b'belt', b'imac', b'eliminate',
# Nearest to b'from': b'and', b'with', b'in', b'suction', b'of', b'eternal', b'gland', b'as',
# Nearest to b'nine': b'zero', b'gland', b'victoriae', b'reginae', b'six', b'analogue', b'seven', b'vs',
# Nearest to b'more': b'lives', b'occasions', b'belonging', b'altenberg', b'receivers', b'unused', b'separated', b'oil',
# Average loss at step  12000 :  14.046884358763695
# Average loss at step  14000 :  11.927863122344018
# Average loss at step  16000 :  10.139787793889642
# Average loss at step  18000 :  8.615291227221489
# Average loss at step  20000 :  7.810306833028793
# Nearest to b'in': b'and', b'on', b'at', b'of', b'with', b'for', b'from', b'nine',
# Nearest to b'six': b'nine', b'eight', b'five', b'four', b'zero', b'seven', b'three', b'two',
# Nearest to b'to': b'with', b'nine', b'and', b'agouti', b'for', b'by', b'dasyprocta', b'in',
# Nearest to b'on': b'in', b'and', b'for', b'tech', b'mathbf', b'sarai', b'by', UNK,
# Nearest to b'but': b'and', b'reginae', b'which', b'is', b'coulomb', b'was', b'adiabatic', b'dasyprocta',
# Nearest to b'i': b'sacred', b'bed', b'syncretism', b'they', b'endowment', b'burnside', b'draw', b'dispersing',
# Nearest to b'were': b'was', b'is', b'are', b'and', b'have', b'lusignan', b'ally', b'forming',
# Nearest to b'such': b'his', b'stayed', b'well', b'credits', b'domicile', b'the', b'store', b'partisan',
# Nearest to b'there': b'it', b'constans', b'britain', b'often', b'decisions', b'and', b'alice', b'artist',
# Nearest to b'b': b'd', b'familiar', b'domitia', b'agouti', b'and', b'companionship', b'proxima', b'nowadays',
# Nearest to b'seven': b'nine', b'six', b'three', b'zero', b'eight', b'five', b'four', b'two',
# Nearest to b'known': b'conducts', b'napalm', b'substituents', b'iii', b'multinational', b'cheaper', b'siege', b'rebel',
# Nearest to b'it': b'he', b'this', b'there', b'they', b'dasyprocta', b'amoeboids', b'which', b'she',
# Nearest to b'from': b'in', b'with', b'and', b'for', b'into', b'of', b'nine', b'by',
# Nearest to b'nine': b'eight', b'six', b'seven', b'zero', b'five', b'four', b'gland', b'victoriae',
# Nearest to b'more': b'lives', b'occasions', b'linguist', b'belonging', b'stream', b'agouti', b'backslash', b'altenberg',
# Average loss at step  22000 :  7.107359979510307
# Average loss at step  24000 :  7.0021922116279605
# Average loss at step  26000 :  6.737228267550469
# Average loss at step  28000 :  6.192591618061066
# Average loss at step  30000 :  6.1923407090902325
# Nearest to b'in': b'and', b'on', b'at', b'of', b'from', b'by', b'with', b'nine',
# Nearest to b'six': b'five', b'eight', b'four', b'nine', b'seven', b'zero', b'three', b'two',
# Nearest to b'to': b'can', b'for', b'would', b'in', b'nine', b'philosophically', b'dasyprocta', b'with',
# Nearest to b'on': b'in', b'and', b'for', b'from', b'by', b'tech', b'two', b'otimes',
# Nearest to b'but': b'and', b'which', b'reginae', b'or', b'coulomb', b'adventist', b'vojt', b'is',
# Nearest to b'i': b'endowment', b'syncretism', b'akita', b'they', b'bed', b'angina', b'sacred', b'callisto',
# Nearest to b'were': b'are', b'was', b'is', b'have', b'by', b'be', b'hoare', b'immense',
# Nearest to b'such': b'well', b'credits', b'stayed', b'domicile', b'store', b'putty', b'reward', b'aegina',
# Nearest to b'there': b'it', b'often', b'constans', b'aba', b'he', b'they', b'sponsors', b'abitibi',
# Nearest to b'b': b'd', b'familiar', b'agouti', b'domitia', b'abitibi', b'nowadays', b'proxima', b'and',
# Nearest to b'seven': b'nine', b'eight', b'five', b'six', b'three', b'four', b'zero', b'two',
# Nearest to b'known': b'well', b'conducts', b'multinational', b'a', b'napalm', b'substituents', b'cheaper', b'intended',
# Nearest to b'it': b'he', b'this', b'there', b'she', b'which', b'they', b'dasyprocta', b'absalom',
# Nearest to b'from': b'in', b'with', b'and', b'into', b'for', b'of', b'by', b'agouti',
# Nearest to b'nine': b'eight', b'six', b'seven', b'five', b'zero', b'four', b'three', b'victoriae',
# Nearest to b'more': b'lives', b'occasions', b'linguist', b'less', b'abitibi', b'belonging', b'stanbul', b'autocad',
# Average loss at step  32000 :  5.8293785030841825
# Average loss at step  34000 :  5.8313016741275785
# Average loss at step  36000 :  5.7138823076486585
# Average loss at step  38000 :  5.26176864695549
# Average loss at step  40000 :  5.463617699861526
# Nearest to b'in': b'at', b'from', b'and', b'on', b'nine', b'of', b'agouti', b'during',
# Nearest to b'six': b'eight', b'five', b'four', b'seven', b'three', b'nine', b'zero', b'two',
# Nearest to b'to': b'can', b'dasyprocta', b'nine', b'for', b'philosophically', b'agouti', b'would', b'reuptake',
# Nearest to b'on': b'in', b'and', b'otimes', b'at', b'from', b'mathbf', b'dasyprocta', b'eponym',
# Nearest to b'but': b'and', b'which', b'reginae', b'however', b'though', b'dasyprocta', b'or', b'vojt',
# Nearest to b'i': b'they', b'endowment', b'bed', b'syncretism', b'akita', b'angina', b'draw', b'janeiro',
# Nearest to b'were': b'are', b'was', b'have', b'is', b'be', b'by', b'been', b'had',
# Nearest to b'such': b'well', b'kayaking', b'domicile', b'credits', b'buckinghamshire', b'some', b'these', b'stayed',
# Nearest to b'there': b'it', b'he', b'often', b'they', b'constans', b'aba', b'which', b'and',
# Nearest to b'b': b'd', UNK, b'familiar', b'agouti', b'domitia', b'abitibi', b'and', b'qa',
# Nearest to b'seven': b'eight', b'six', b'five', b'nine', b'four', b'three', b'zero', b'two',
# Nearest to b'known': b'well', b'multinational', b'cheaper', b'conducts', b'substituents', b'considered', b'capacitor', b'napalm',
# Nearest to b'it': b'he', b'this', b'she', b'there', b'which', b'they', b'dasyprocta', b'that',
# Nearest to b'from': b'in', b'into', b'with', b'agouti', b'and', b'recitative', b'on', b'between',
# Nearest to b'nine': b'eight', b'seven', b'six', b'zero', b'five', b'four', b'three', b'victoriae',
# Nearest to b'more': b'less', b'occasions', b'lives', b'abitibi', b'linguist', b'agouti', b'autocad', b'belonging',
# Average loss at step  42000 :  5.286029880046844
# Average loss at step  44000 :  5.281632693171501
# Average loss at step  46000 :  5.263445863008499
# Average loss at step  48000 :  5.033664837956429
# Average loss at step  50000 :  5.148048001050949
# Nearest to b'in': b'and', b'at', b'from', b'on', b'nine', b'of', b'during', b'thibetanus',
# Nearest to b'six': b'four', b'eight', b'five', b'seven', b'three', b'nine', b'two', b'one',
# Nearest to b'to': b'philosophically', b'would', b'for', b'can', b'agouti', b'reuptake', b'dasyprocta', b'nine',
# Nearest to b'on': b'in', b'and', b'at', b'otimes', b'upon', b'for', b'dasyprocta', b'mathbf',
# Nearest to b'but': b'and', b'however', b'which', b'reginae', b'though', b'or', b'vojt', b'dasyprocta',
# Nearest to b'i': b'they', b'endowment', b'imperfective', b'syncretism', b'bed', b'angina', b'guderian', b'akita',
# Nearest to b'were': b'are', b'was', b'have', b'is', b'be', b'had', b'by', b'been',
# Nearest to b'such': b'well', b'these', b'kayaking', b'buckinghamshire', b'some', b'thibetanus', b'bock', b'served',
# Nearest to b'there': b'it', b'they', b'often', b'he', b'constans', b'aba', b'which', b'generally',
# Nearest to b'b': b'd', b'agouti', b'naaman', b'six', UNK, b'familiar', b'thibetanus', b'abitibi',
# Nearest to b'seven': b'eight', b'six', b'five', b'four', b'nine', b'three', b'zero', b'thibetanus',
# Nearest to b'known': b'well', b'bock', b'multinational', b'such', b'seen', b'cheaper', b'capacitor', b'intended',
# Nearest to b'it': b'he', b'this', b'she', b'there', b'they', b'which', b'thibetanus', b'absalom',
# Nearest to b'from': b'in', b'into', b'and', b'nine', b'with', b'for', b'agouti', b'recitative',
# Nearest to b'nine': b'eight', b'seven', b'six', b'zero', b'four', b'five', b'three', b'thibetanus',
# Nearest to b'more': b'less', b'lives', b'most', b'occasions', b'gysin', b'linguist', b'abitibi', b'woolfson',
# Average loss at step  52000 :  5.1635296672582625
# Average loss at step  54000 :  5.110265508413315
# Average loss at step  56000 :  5.052637277364731
# Average loss at step  58000 :  5.105928806781769
# Average loss at step  60000 :  4.941589298725128
# Nearest to b'in': b'from', b'at', b'and', b'on', b'of', b'during', b'lar', b'callithrix',
# Nearest to b'six': b'eight', b'five', b'four', b'three', b'seven', b'nine', b'zero', b'two',
# Nearest to b'to': b'would', b'must', b'can', b'philosophically', b'will', b'for', b'not', b'cebus',
# Nearest to b'on': b'in', b'upon', b'and', b'at', b'callithrix', b'satisfiable', b'dasyprocta', b'otimes',
# Nearest to b'but': b'and', b'however', b'which', b'reginae', b'though', b'or', b'ssbn', b'tamarin',
# Nearest to b'i': b'they', b'endowment', b't', b'syncretism', b'imperfective', b'bradford', b'angina', b'janeiro',
# Nearest to b'were': b'are', b'was', b'have', b'had', b'be', b'by', b'is', b'been',
# Nearest to b'such': b'well', b'these', b'some', b'known', b'buckinghamshire', b'bock', b'kayaking', b'thibetanus',
# Nearest to b'there': b'it', b'they', b'he', b'often', b'constans', b'which', b'generally', b'aba',
# Nearest to b'b': b'd', b'naaman', b'microcebus', UNK, b'agouti', b'thibetanus', b'six', b'familiar',
# Nearest to b'seven': b'eight', b'six', b'nine', b'five', b'four', b'three', b'zero', b'one',
# Nearest to b'known': b'well', b'used', b'seen', b'such', b'brahui', b'considered', b'multinational', b'intended',
# Nearest to b'it': b'he', b'this', b'she', b'there', b'which', b'they', b'thibetanus', b'absalom',
# Nearest to b'from': b'in', b'into', b'and', b'under', b'with', b'between', b'of', b'by',
# Nearest to b'nine': b'eight', b'six', b'seven', b'five', b'four', b'three', b'zero', b'thibetanus',
# Nearest to b'more': b'less', b'most', b'lives', b'occasions', b'gysin', b'agouti', b'woolfson', b'autocad',
# Average loss at step  62000 :  4.792339663624763
# Average loss at step  64000 :  4.799357338547707
# Average loss at step  66000 :  4.978193167686462
# Average loss at step  68000 :  4.922262207746506
# Average loss at step  70000 :  4.766399360656738
# Nearest to b'in': b'during', b'on', b'at', b'from', b'callithrix', b'lar', b'thibetanus', b'mitral',
# Nearest to b'six': b'eight', b'four', b'five', b'seven', b'three', b'nine', b'zero', b'two',
# Nearest to b'to': b'can', b'would', b'must', b'will', b'philosophically', b'for', b'leontopithecus', b'noether',
# Nearest to b'on': b'in', b'upon', b'at', b'and', b'satisfiable', b'eponym', b'callithrix', b'suborders',
# Nearest to b'but': b'and', b'however', b'which', b'though', b'reginae', b'ssbn', b'tamarin', b'or',
# Nearest to b'i': b'they', b'endowment', b'syncretism', b'ii', b'bradford', b'callisto', b'akita', b't',
# Nearest to b'were': b'are', b'was', b'have', b'be', b'had', b'been', b'by', b'is',
# Nearest to b'such': b'well', b'these', b'some', b'known', b'buckinghamshire', b'served', b'bock', b'many',
# Nearest to b'there': b'it', b'they', b'often', b'he', b'generally', b'constans', b'which', b'this',
# Nearest to b'b': b'd', UNK, b'naaman', b'microcebus', b'agouti', b'thibetanus', b'three', b'familiar',
# Nearest to b'seven': b'eight', b'six', b'four', b'three', b'five', b'nine', b'zero', b'one',
# Nearest to b'known': b'well', b'used', b'seen', b'such', b'considered', b'multinational', b'brahui', b'deterrent',
# Nearest to b'it': b'he', b'this', b'she', b'there', b'they', b'which', b'absalom', b'thaler',
# Nearest to b'from': b'into', b'in', b'between', b'with', b'under', b'within', b'nine', b'agouti',
# Nearest to b'nine': b'eight', b'seven', b'six', b'five', b'zero', b'four', b'three', b'thibetanus',
# Nearest to b'more': b'less', b'most', b'lives', b'occasions', b'smaller', b'gysin', b'agouti', b'very',
# Average loss at step  72000 :  4.792921798348427
# Average loss at step  74000 :  4.780293796777725
# Average loss at step  76000 :  4.880804695129394
# Average loss at step  78000 :  4.807951219320297
# Average loss at step  80000 :  4.803148362517357
# Nearest to b'in': b'during', b'at', b'cegep', b'from', b'on', b'callithrix', b'within', b'since',
# Nearest to b'six': b'four', b'five', b'seven', b'eight', b'three', b'nine', b'two', b'zero',
# Nearest to b'to': b'will', b'must', b'would', b'philosophically', b'cegep', b'noether', b'can', b'dasyprocta',
# Nearest to b'on': b'in', b'upon', b'at', b'cegep', b'during', b'callithrix', b'otimes', b'suborders',
# Nearest to b'but': b'however', b'and', b'which', b'reginae', b'though', b'ssbn', b'tamarin', b'pontificia',
# Nearest to b'i': b'they', b't', b'ii', UNK, b'syncretism', b'motors', b'endowment', b'janeiro',
# Nearest to b'were': b'are', b'was', b'have', b'had', b'be', b'been', b'by', b'being',
# Nearest to b'such': b'well', b'these', b'known', b'some', b'many', b'served', b'buckinghamshire', b'bock',
# Nearest to b'there': b'it', b'they', b'often', b'he', b'generally', b'which', b'constans', b'this',
# Nearest to b'b': b'd', UNK, b'naaman', b'microcebus', b'agouti', b'three', b'thibetanus', b'abitibi',
# Nearest to b'seven': b'eight', b'six', b'four', b'five', b'three', b'nine', b'zero', b'one',
# Nearest to b'known': b'used', b'well', b'seen', b'such', b'intended', b'considered', b'brahui', b'deterrent',
# Nearest to b'it': b'he', b'she', b'this', b'there', b'they', b'which', b'thibetanus', b'absalom',
# Nearest to b'from': b'into', b'in', b'by', b'between', b'within', b'and', b'with', b'across',
# Nearest to b'nine': b'eight', b'seven', b'six', b'five', b'four', b'zero', b'three', b'cegep',
# Nearest to b'more': b'less', b'most', b'lives', b'smaller', b'occasions', b'quite', b'very', b'gysin',
# Average loss at step  82000 :  4.808453744649887
# Average loss at step  84000 :  4.784714750647545
# Average loss at step  86000 :  4.742509938836098
# Average loss at step  88000 :  4.695827189445495
# Average loss at step  90000 :  4.7495763679742815
# Nearest to b'in': b'during', b'cegep', b'at', b'within', b'tamias', b'nine', b'from', b'callithrix',
# Nearest to b'six': b'seven', b'eight', b'five', b'four', b'three', b'nine', b'zero', b'two',
# Nearest to b'to': b'would', b'will', b'must', b'can', b'cegep', b'for', b'philosophically', b'cebus',
# Nearest to b'on': b'in', b'at', b'upon', b'cegep', b'tamias', b'otimes', b'callithrix', b'suborders',
# Nearest to b'but': b'however', b'and', b'which', b'though', b'reginae', b'while', b'or', b'tamarin',
# Nearest to b'i': b'they', b't', b'ii', b'f', b'syncretism', b'you', b'akita', b'motors',
# Nearest to b'were': b'are', b'was', b'have', b'had', b'be', b'been', b'is', b'by',
# Nearest to b'such': b'well', b'these', b'known', b'some', b'many', b'served', b'buckinghamshire', b'bock',
# Nearest to b'there': b'they', b'it', b'he', b'often', b'which', b'generally', b'constans', b'aba',
# Nearest to b'b': b'd', UNK, b'naaman', b'agouti', b'microcebus', b'three', b'thibetanus', b'c',
# Nearest to b'seven': b'eight', b'six', b'five', b'four', b'nine', b'three', b'zero', b'one',
# Nearest to b'known': b'used', b'well', b'seen', b'such', b'considered', b'intended', b'brahui', b'deterrent',
# Nearest to b'it': b'he', b'she', b'this', b'there', b'which', b'they', b'absalom', b'thaler',
# Nearest to b'from': b'into', b'in', b'within', b'under', b'across', b'with', b'between', b'through',
# Nearest to b'nine': b'eight', b'seven', b'six', b'five', b'four', b'zero', b'cegep', b'callithrix',
# Nearest to b'more': b'less', b'most', b'very', b'smaller', b'lives', b'quite', b'gysin', b'tamias',
# Average loss at step  92000 :  4.709150791883468
# Average loss at step  94000 :  4.636258371949196
# Average loss at step  96000 :  4.725686373949051
# Average loss at step  98000 :  4.616494933247567
# Average loss at step  100000 :  4.671715732812881
# Nearest to b'in': b'during', b'cegep', b'tamias', b'at', b'on', b'from', b'within', b'callithrix',
# Nearest to b'six': b'seven', b'five', b'four', b'eight', b'nine', b'three', b'two', b'zero',
# Nearest to b'to': b'must', b'will', b'can', b'would', b'cegep', b'philosophically', b'agouti', b'marmoset',
# Nearest to b'on': b'in', b'upon', b'at', b'cegep', b'during', b'tamias', b'through', b'callithrix',
# Nearest to b'but': b'and', b'however', b'which', b'though', b'while', b'reginae', b'although', b'tamarin',
# Nearest to b'i': b'they', b'you', b'ii', b't', b'syncretism', b'f', b'motors', b'akita',
# Nearest to b'were': b'are', b'was', b'have', b'had', b'is', b'be', b'by', b'although',
# Nearest to b'such': b'well', b'these', b'known', b'some', b'many', b'served', b'buckinghamshire', b'bock',
# Nearest to b'there': b'they', b'it', b'he', b'often', b'which', b'generally', b'constans', b'lemmy',
# Nearest to b'b': b'd', b'familiar', b'microcebus', b'agouti', b'naaman', b'thibetanus', b'pins', b'yttrium',
# Nearest to b'seven': b'six', b'eight', b'five', b'four', b'nine', b'three', b'zero', b'two',
# Nearest to b'known': b'used', b'seen', b'such', b'well', b'considered', b'intended', b'callithrix', b'brahui',
# Nearest to b'it': b'he', b'she', b'this', b'there', b'they', b'which', b'eurocents', b'absalom',
# Nearest to b'from': b'into', b'in', b'within', b'across', b'between', b'under', b'majestic', b'with',
# Nearest to b'nine': b'eight', b'seven', b'six', b'five', b'four', b'zero', b'cegep', b'callithrix',
# Nearest to b'more': b'less', b'most', b'very', b'lives', b'smaller', b'tamias', b'woolfson', b'quite',

# %%
# Step 6: embeddings을 시각화한다.

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print("Please install sklearn and matplotlib to visualize embeddings.")

# %%
from IPython.display import Image
Image(filename='tsne.png')
